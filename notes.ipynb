# %% [markdown]
# # Data
#
# You are given three files.
# - Each file corresponds to a word (director, overtime, rubbish).
# - For each word, the file listed two senses of each word, used as a noun.
# - Some of these words may have more than 2
# senses;
# - those extra senses are ignored.
#
#
# ### Each file contains
# - the word,
# - the gloss of the two senses that are to be disambiguated.
# - Also, for each sense,
#     - there are 25 sentences that contain the word and have the specified sense
#     - (notice that the word may be in plural form).
#     - There is no guarantee that the sentence would not contain grammatical and spelling mistakes.

# %% [markdown]
# # Stage 1: Beefing up the data set (10 points)
# - Each group should pick one word, and
# - produce 3 new sentences for each of the two senses of that word,
# - that is sufficiently different than the sentences already in the data set.
# - There will be a discussion board on Canvas where you can post the sentences.
# - Every group is allowed to use the new sentences anyway it pleases (or to ignore them).
#
# ##### This should be done by 11/17 (Tue) 11:59pm.

# %% [markdown]
# ### essentially: Each group should pick one word, and produce 3 new sentences for each of the two senses of that word

# %% [markdown]
# # WORD: Overtime
#
# ## Senses:
# 1. work done in addition to regular working hours
# - I cannot believe I worked unpaid overtime this week.
# - I love working overtime at my job, because I get paid time and a half.
# - Sometimes when I work overtime, I just sit at my desk and play games on my computer.
#
# 2. playing time beyond regulation, to break a tie
# - I want this game to go into overtime so that I can enjoy more time at the game with my family.
# - Overtime in the game was too tense for me to handle yesterday.
# - I think overtime can drain players of their energy.
